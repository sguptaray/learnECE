# %% [markdown]
# # Binary prediction experiment results with transformer for event sequences

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive/Colab Notebooks/NLP/project/PC-TES-PROJECT/causality-guided-Transformer
# Out:
# /content/drive/MyDrive/Colab Notebooks/NLP/project/PC-TES-PROJECT/causality-guided-Transformer

# %%
beige = pd.read_csv('results/beige_log.txt',sep=',',header=None)
beige.columns = ['event','valid_ll','test_ll']
idx = beige.groupby('event')['valid_ll'].transform(max) == beige['valid_ll']
beige[idx].agg({'test_ll':'mean'})
# Out:
# <ipython-input-6-67f8bcf6ca1c>:3: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   idx = beige.groupby('event')['valid_ll'].transform(max) == beige['valid_ll']
# test_ll   -20.38108
# dtype: float64
