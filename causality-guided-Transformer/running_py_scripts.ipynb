# %% [markdown]
# The following 2 lines of code are helpful every time you need change directories. Make sure to disconnect and delete runtime before running these 2 lines of code.
#
# Some of the python files require GPU.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive/Colab Notebooks/NLP/project/PC-TES-PROJECT/causality-guided-Transformer
# Out:
# /content/drive/MyDrive/Colab Notebooks/NLP/project/PC-TES-PROJECT/causality-guided-Transformer

# %%
# !python TES_beigebooks.py
# Out:
# [Info] parameters: ArgumentParser(prog='TES_beigebooks.py', usage=None, description=None, formatter_class=<class 'argparse.HelpFormatter'>, conflict_handler='error', add_help=True)
# [Info] Loading train data...
# [Info] Loading dev data...
# [Info] Loading test data...
# [Info] Number of parameters: 1318928
# [ Epoch 1 ]
#   - (Training)     loglikelihood: -23.5387 ,elapse: 0.037 min
#   - (validation)  loglikelihood: -51.3841elapse: 0.001 min
#   - (test)  loglikelihood: -49.1910elapse: 0.001 min
#   - [Info] Maximum validation loglikelihood:-51.3841
# [ Epoch 2 ]
#   - (Training)     loglikelihood: -19.0902 ,elapse: 0.003 min
#   - (validation)  loglikelihood: -38.4595elapse: 0.002 min
#   - (test)  loglikelihood: -37.2660elapse: 0.001 min
#   - [Info] Maximum validation loglikelihood:-38.4595
# [ Epoch 3 ]
#   - (Training)     loglikelihood: -15.6894 ,elapse: 0.003 min
#   - (validation)  loglikelihood: -28.8710elapse: 0.002 min
# ...

# %%
# !python PAIN_beigebooks.py
# Out:
# [Info] parameters: ArgumentParser(prog='PAIN_beigebooks.py', usage=None, description=None, formatter_class=<class 'argparse.HelpFormatter'>, conflict_handler='error', add_help=True)
# [Info] Loading train data...
# [Info] Loading dev data...
# [Info] Loading test data...
# [Info] Loading prior ...
# [Info] Number of parameters: 331967
# [ Epoch 1 ]
#   - (Training)     KL:  52.1992, loglikelihood: -28.8184 ,elapse: 0.035 min
#   - (validation)  loglikelihood: -66.2516elapse: 0.003 min
#   - (test)  loglikelihood: -62.3976elapse: 0.002 min
#   - [Info] Maximum validation loglikelihood:-66.2516
# [ Epoch 2 ]
#   - (Training)     KL:  52.1589, loglikelihood: -27.5492 ,elapse: 0.004 min
#   - (validation)  loglikelihood: -63.7348elapse: 0.002 min
#   - (test)  loglikelihood: -57.5441elapse: 0.002 min
#   - [Info] Maximum validation loglikelihood:-63.7348
# [ Epoch 3 ]
#   - (Training)     KL:  52.1184, loglikelihood: -26.6414 ,elapse: 0.004 min
# ...

# %%
# !python Main_TES.py -data data/beigebooks_data/ -epoch 10  -batch_size 16 -d_model 512 -d_inner 256 -d_k 256 -d_v 256 -n_head 4 -n_layers 4 -dropout 0.1 -lr 1e-4 -log beige_log.txt
# Out:
# [Info] parameters: Namespace(data='data/beigebooks_data/', epoch=10, batch_size=16, d_model=512, d_inner=256, d_k=256, d_v=256, n_head=4, n_layers=4, dropout=0.1, lr=0.0001, log='beige_log.txt', device=device(type='cuda'))
# [Info] Loading train data...
# [Info] Loading dev data...
# [Info] Loading test data...
# [Info] Number of parameters: 9466623
# [ Epoch 1 ]
#   - (Training)     loglikelihood:  -9.3452 ,elapse: 0.019 min
#   - (validation)  loglikelihood: -88.1746elapse: 0.002 min
#   - (test)  loglikelihood: -97.7431elapse: 0.002 min
#   - [Info] Maximum validation loglikelihood:-88.1746
# [ Epoch 2 ]
#   - (Training)     loglikelihood:  -8.0725 ,elapse: 0.005 min
#   - (validation)  loglikelihood: -58.5003elapse: 0.002 min
#   - (test)  loglikelihood: -72.6632elapse: 0.002 min
#   - [Info] Maximum validation loglikelihood:-58.5003
# [ Epoch 3 ]
#   - (Training)     loglikelihood:  -6.7061 ,elapse: 0.004 min
#   - (validation)  loglikelihood: -44.2385elapse: 0.002 min
# ...

# %% [markdown]
# Decompiling pickle files

# %%
# %cd drive/MyDrive/Colab Notebooks/NLP/project/PC-TES-PROJECT/causality-guided-Transformer/prior/beigebooks/sparse
# Out:
# /content/drive/MyDrive/Colab Notebooks/NLP/project/PC-TES-PROJECT/causality-guided-Transformer/prior/beigebooks/sparse

# %%
import pickle

with open('prior.pkl', 'rb') as f:
    data = pickle.load(f)

print(data)
# Out:
# tensor([[0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000,
#          0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000,
#          0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000,
#          0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000,
#          0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000,
#          0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000,
#          0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000,
# ...

# %%
print(data.ndim) # number of dimensions (rank)
# Out:
# 2

# %%
print(data.shape) # size of each dimension
# Out:
# torch.Size([15, 15])

# %%
# %cd drive/MyDrive/Colab Notebooks/NLP/project/PC-TES-PROJECT/causality-guided-Transformer/data/beigebooks_data
# Out:
# /content/drive/MyDrive/Colab Notebooks/NLP/project/PC-TES-PROJECT/causality-guided-Transformer/data/beigebooks_data

# %%
import pickle
import pprint

# %%
with open('dev.pkl', 'rb') as f:
    data_dev = pickle.load(f)

print(data_dev)
# Out:
# {'dim_process': 15, 'devtest': [], 'args': None, 'dev': [[{'time_since_start': 1, 'time_since_last_event': 0, 'type_event': 14}, {'time_since_start': 2, 'time_since_last_event': 1, 'type_event': 12}], [{'time_since_start': 1, 'time_since_last_event': 0, 'type_event': 14}, {'time_since_start': 2, 'time_since_last_event': 1, 'type_event': 4}, {'time_since_start': 3, 'time_since_last_event': 1, 'type_event': 3}, {'time_since_start': 4, 'time_since_last_event': 1, 'type_event': 13}, {'time_since_start': 5, 'time_since_last_event': 1, 'type_event': 1}, {'time_since_start': 6, 'time_since_last_event': 1, 'type_event': 6}, {'time_since_start': 7, 'time_since_last_event': 1, 'type_event': 2}, {'time_since_start': 8, 'time_since_last_event': 1, 'type_event': 7}, {'time_since_start': 9, 'time_since_last_event': 1, 'type_event': 8}, {'time_since_start': 10, 'time_since_last_event': 1, 'type_event': 5}, {'time_since_start': 11, 'time_since_last_event': 1, 'type_event': 9}, {'time_since_start': 1
# ...

# %%
pprint.pp(data_dev)
# Out:
# {'dim_process': 15,
#  'devtest': [],
#  'args': None,
#  'dev': [[{'time_since_start': 1, 'time_since_last_event': 0, 'type_event': 14},
#           {'time_since_start': 2,
#            'time_since_last_event': 1,
#            'type_event': 12}],
#          [{'time_since_start': 1, 'time_since_last_event': 0, 'type_event': 14},
#           {'time_since_start': 2, 'time_since_last_event': 1, 'type_event': 4},
#           {'time_since_start': 3, 'time_since_last_event': 1, 'type_event': 3},
#           {'time_since_start': 4, 'time_since_last_event': 1, 'type_event': 13},
#           {'time_since_start': 5, 'time_since_last_event': 1, 'type_event': 1},
#           {'time_since_start': 6, 'time_since_last_event': 1, 'type_event': 6},
#           {'time_since_start': 7, 'time_since_last_event': 1, 'type_event': 2},
#           {'time_since_start': 8, 'time_since_last_event': 1, 'type_event': 7},
#           {'time_since_start': 9, 'time_since_last_event': 1, 'type_event': 8},
# ...

# %%
print(len(data_dev))
# Out:
# 6

# %%
print(len(data_dev['dev']))
# Out:
# 52

# %%
with open('test.pkl', 'rb') as f:
    data_test = pickle.load(f)

print(data_test)
# Out:
# {'dim_process': 15, 'devtest': [], 'args': None, 'dev': [], 'train': [], 'test': [[{'time_since_start': 1, 'time_since_last_event': 0, 'type_event': 14}, {'time_since_start': 2, 'time_since_last_event': 1, 'type_event': 4}, {'time_since_start': 3, 'time_since_last_event': 1, 'type_event': 3}, {'time_since_start': 4, 'time_since_last_event': 1, 'type_event': 13}, {'time_since_start': 5, 'time_since_last_event': 1, 'type_event': 1}, {'time_since_start': 6, 'time_since_last_event': 1, 'type_event': 6}, {'time_since_start': 7, 'time_since_last_event': 1, 'type_event': 2}, {'time_since_start': 8, 'time_since_last_event': 1, 'type_event': 7}, {'time_since_start': 9, 'time_since_last_event': 1, 'type_event': 5}, {'time_since_start': 10, 'time_since_last_event': 1, 'type_event': 8}, {'time_since_start': 11, 'time_since_last_event': 1, 'type_event': 9}, {'time_since_start': 12, 'time_since_last_event': 1, 'type_event': 15}, {'time_since_start': 13, 'time_since_last_event': 1, 'type_event': 10
# ...

# %%
pprint.pp(data_test)
# Out:
# {'dim_process': 15,
#  'devtest': [],
#  'args': None,
#  'dev': [],
#  'train': [],
#  'test': [[{'time_since_start': 1,
#             'time_since_last_event': 0,
#             'type_event': 14},
#            {'time_since_start': 2, 'time_since_last_event': 1, 'type_event': 4},
#            {'time_since_start': 3, 'time_since_last_event': 1, 'type_event': 3},
#            {'time_since_start': 4,
#             'time_since_last_event': 1,
#             'type_event': 13},
#            {'time_since_start': 5, 'time_since_last_event': 1, 'type_event': 1},
#            {'time_since_start': 6, 'time_since_last_event': 1, 'type_event': 6},
#            {'time_since_start': 7, 'time_since_last_event': 1, 'type_event': 2},
#            {'time_since_start': 8, 'time_since_last_event': 1, 'type_event': 7},
#            {'time_since_start': 9, 'time_since_last_event': 1, 'type_event': 5},
#            {'time_since_start': 10,
#             'time_since_last_event': 1,
# ...

# %%
print(len(data_test))
# Out:
# 6

# %%
print(len(data_test['test']))
# Out:
# 52

# %%
with open('train.pkl', 'rb') as f:
    data_train = pickle.load(f)

print(data_train)
# Out:
# {'dim_process': 15, 'devtest': [], 'args': None, 'dev': [], 'train': [[{'time_since_start': 1, 'time_since_last_event': 0, 'type_event': 4}], [{'time_since_start': 1, 'time_since_last_event': 0, 'type_event': 14}, {'time_since_start': 2, 'time_since_last_event': 1, 'type_event': 4}, {'time_since_start': 3, 'time_since_last_event': 1, 'type_event': 3}, {'time_since_start': 4, 'time_since_last_event': 1, 'type_event': 13}, {'time_since_start': 5, 'time_since_last_event': 1, 'type_event': 1}, {'time_since_start': 6, 'time_since_last_event': 1, 'type_event': 6}, {'time_since_start': 7, 'time_since_last_event': 1, 'type_event': 2}, {'time_since_start': 8, 'time_since_last_event': 1, 'type_event': 7}, {'time_since_start': 9, 'time_since_last_event': 1, 'type_event': 5}, {'time_since_start': 10, 'time_since_last_event': 1, 'type_event': 8}, {'time_since_start': 11, 'time_since_last_event': 1, 'type_event': 9}, {'time_since_start': 12, 'time_since_last_event': 1, 'type_event': 15}, {'time_si
# ...

# %%
pprint.pp(data_train)
# Out:
# {'dim_process': 15,
#  'devtest': [],
#  'args': None,
#  'dev': [],
#  'train': [[{'time_since_start': 1,
#              'time_since_last_event': 0,
#              'type_event': 4}],
#            [{'time_since_start': 1,
#              'time_since_last_event': 0,
#              'type_event': 14},
#             {'time_since_start': 2,
#              'time_since_last_event': 1,
#              'type_event': 4},
#             {'time_since_start': 3,
#              'time_since_last_event': 1,
#              'type_event': 3},
#             {'time_since_start': 4,
#              'time_since_last_event': 1,
#              'type_event': 13},
#             {'time_since_start': 5,
#              'time_since_last_event': 1,
#              'type_event': 1},
#             {'time_since_start': 6,
#              'time_since_last_event': 1,
#              'type_event': 6},
#             {'time_since_start': 7,
#              'time_since_last_event': 1,
#              'type_event': 2},
# ...

# %%
print(len(data_train))
# Out:
# 6

# %%
print(len(data_train['train']))
# Out:
# 156
